# %%
import pandas as pd
import numpy as np
import pylab as plt

# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10, 5))

# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (10, 10)
# Size of matplotlib histogram bins
bin_size = 10

# %%
raw_df = pd.read_csv('./train.csv')
df = raw_df[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']].copy()
#for col in ['Sex', 'Embarked']:
#    df[col] = df[col].astype('category')
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male   NaN      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# 13          0       3    male  39.0      1      5   31.2750        S
# 14          0       3  female  14.0      0      0    7.8542        S
# 15          1       2  female  55.0      0      0   16.0000        S
# 16          0       3    male   2.0      4      1   29.1250        Q
# 17          1       2    male   NaN      0      0   13.0000        S
# 18          0       3  female  31.0      1      0   18.0000        S
# 19          1       3  female   NaN      0      0    7.2250        C
# 20          0       2    male  35.0      0      0   26.0000        S
# 21          1       2    male  34.0      0      0   13.0000        S
# 22          1       3  female  15.0      0      0    8.0292        Q
# 23          1       1    male  28.0      0      0   35.5000        S
# 24          0       3  female   8.0      3      1   21.0750        S
# 25          1       3  female  38.0      1      5   31.3875        S
# 26          0       3    male   NaN      0      0    7.2250        C
# 27          0       1    male  19.0      3      2  263.0000        S
# 28          1       3  female   NaN      0      0    7.8792        Q
# 29          0       3    male   NaN      0      0    7.8958        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 861         0       2    male  21.0      1      0   11.5000        S
# 862         1       1  female  48.0      0      0   25.9292        S
# 863         0       3  female   NaN      8      2   69.5500        S
# 864         0       2    male  24.0      0      0   13.0000        S
# 865         1       2  female  42.0      0      0   13.0000        S
# 866         1       2  female  27.0      1      0   13.8583        C
# 867         0       1    male  31.0      0      0   50.4958        S
# 868         0       3    male   NaN      0      0    9.5000        S
# 869         1       3    male   4.0      1      1   11.1333        S
# 870         0       3    male  26.0      0      0    7.8958        S
# 871         1       1  female  47.0      1      1   52.5542        S
# 872         0       1    male  33.0      0      0    5.0000        S
# 873         0       3    male  47.0      0      0    9.0000        S
# 874         1       2  female  28.0      1      0   24.0000        C
# 875         1       3  female  15.0      0      0    7.2250        C
# 876         0       3    male  20.0      0      0    9.8458        S
# 877         0       3    male  19.0      0      0    7.8958        S
# 878         0       3    male   NaN      0      0    7.8958        S
# 879         1       1  female  56.0      0      1   83.1583        C
# 880         1       2  female  25.0      0      1   26.0000        S
# 881         0       3    male  33.0      0      0    7.8958        S
# 882         0       3  female  22.0      0      0   10.5167        S
# 883         0       2    male  28.0      0      0   10.5000        S
# 884         0       3    male  25.0      0      0    7.0500        S
# 885         0       3  female  39.0      0      5   29.1250        Q
# 886         0       2    male  27.0      0      0   13.0000        S
# 887         1       1  female  19.0      0      0   30.0000        S
# 888         0       3  female   NaN      1      2   23.4500        S
# 889         1       1    male  26.0      0      0   30.0000        C
# 890         0       3    male  32.0      0      0    7.7500        Q
#
# [891 rows x 8 columns]

# %%
#df.isnull().sum()
#df[df.Embarked.isnull()]

df['Sex'].unique()
sexes = sorted(df['Sex'].unique())
genders_mapping = dict(zip(sexes, range(0, len(sexes) + 1)))
df['Sex_Val'] = df['Sex'].map(genders_mapping).astype(int)

df['Embarked'].fillna('-', inplace=True)
embarked_locs = sorted(df['Embarked'].unique())
embarked_locs_mapping = dict(zip(embarked_locs, range(0, len(embarked_locs) + 1)))
embarked_locs_mapping
df['Embarked_Val'] = df['Embarked'].map(embarked_locs_mapping).astype(int)

df['AgeFill'] = df['Age']
df['AgeFill'] = df['AgeFill'].groupby([df['Sex_Val'], df['Pclass']]).apply(lambda x: x.fillna(x.median()))
        
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Sex_Val  \
# 0           0       3    male  22.0      1      0    7.2500        S        1
# 1           1       1  female  38.0      1      0   71.2833        C        0
# 2           1       3  female  26.0      0      0    7.9250        S        0
# 3           1       1  female  35.0      1      0   53.1000        S        0
# 4           0       3    male  35.0      0      0    8.0500        S        1
# 5           0       3    male   NaN      0      0    8.4583        Q        1
# 6           0       1    male  54.0      0      0   51.8625        S        1
# 7           0       3    male   2.0      3      1   21.0750        S        1
# 8           1       3  female  27.0      0      2   11.1333        S        0
# 9           1       2  female  14.0      1      0   30.0708        C        0
# 10          1       3  female   4.0      1      1   16.7000        S        0
# 11          1       1  female  58.0      0      0   26.5500        S        0
# 12          0       3    male  20.0      0      0    8.0500        S        1
# 13          0       3    male  39.0      1      5   31.2750        S        1
# 14          0       3  female  14.0      0      0    7.8542        S        0
# 15          1       2  female  55.0      0      0   16.0000        S        0
# 16          0       3    male   2.0      4      1   29.1250        Q        1
# 17          1       2    male   NaN      0      0   13.0000        S        1
# 18          0       3  female  31.0      1      0   18.0000        S        0
# 19          1       3  female   NaN      0      0    7.2250        C        0
# 20          0       2    male  35.0      0      0   26.0000        S        1
# 21          1       2    male  34.0      0      0   13.0000        S        1
# 22          1       3  female  15.0      0      0    8.0292        Q        0
# 23          1       1    male  28.0      0      0   35.5000        S        1
# 24          0       3  female   8.0      3      1   21.0750        S        0
# 25          1       3  female  38.0      1      5   31.3875        S        0
# 26          0       3    male   NaN      0      0    7.2250        C        1
# 27          0       1    male  19.0      3      2  263.0000        S        1
# 28          1       3  female   NaN      0      0    7.8792        Q        0
# 29          0       3    male   NaN      0      0    7.8958        S        1
# ..        ...     ...     ...   ...    ...    ...       ...      ...      ...
# 861         0       2    male  21.0      1      0   11.5000        S        1
# 862         1       1  female  48.0      0      0   25.9292        S        0
# 863         0       3  female   NaN      8      2   69.5500        S        0
# 864         0       2    male  24.0      0      0   13.0000        S        1
# 865         1       2  female  42.0      0      0   13.0000        S        0
# 866         1       2  female  27.0      1      0   13.8583        C        0
# 867         0       1    male  31.0      0      0   50.4958        S        1
# 868         0       3    male   NaN      0      0    9.5000        S        1
# 869         1       3    male   4.0      1      1   11.1333        S        1
# 870         0       3    male  26.0      0      0    7.8958        S        1
# 871         1       1  female  47.0      1      1   52.5542        S        0
# 872         0       1    male  33.0      0      0    5.0000        S        1
# 873         0       3    male  47.0      0      0    9.0000        S        1
# 874         1       2  female  28.0      1      0   24.0000        C        0
# 875         1       3  female  15.0      0      0    7.2250        C        0
# 876         0       3    male  20.0      0      0    9.8458        S        1
# 877         0       3    male  19.0      0      0    7.8958        S        1
# 878         0       3    male   NaN      0      0    7.8958        S        1
# 879         1       1  female  56.0      0      1   83.1583        C        0
# 880         1       2  female  25.0      0      1   26.0000        S        0
# 881         0       3    male  33.0      0      0    7.8958        S        1
# 882         0       3  female  22.0      0      0   10.5167        S        0
# 883         0       2    male  28.0      0      0   10.5000        S        1
# 884         0       3    male  25.0      0      0    7.0500        S        1
# 885         0       3  female  39.0      0      5   29.1250        Q        0
# 886         0       2    male  27.0      0      0   13.0000        S        1
# 887         1       1  female  19.0      0      0   30.0000        S        0
# 888         0       3  female   NaN      1      2   23.4500        S        0
# 889         1       1    male  26.0      0      0   30.0000        C        1
# 890         0       3    male  32.0      0      0    7.7500        Q        1
#
#      Embarked_Val  AgeFill
# 0               3     22.0
# 1               1     38.0
# 2               3     26.0
# 3               3     35.0
# 4               3     35.0
# 5               2     25.0
# 6               3     54.0
# 7               3      2.0
# 8               3     27.0
# 9               1     14.0
# 10              3      4.0
# 11              3     58.0
# 12              3     20.0
# 13              3     39.0
# 14              3     14.0
# 15              3     55.0
# 16              2      2.0
# 17              3     30.0
# 18              3     31.0
# 19              1     21.5
# 20              3     35.0
# 21              3     34.0
# 22              2     15.0
# 23              3     28.0
# 24              3      8.0
# 25              3     38.0
# 26              1     25.0
# 27              3     19.0
# 28              2     21.5
# 29              3     25.0
# ..            ...      ...
# 861             3     21.0
# 862             3     48.0
# 863             3     21.5
# 864             3     24.0
# 865             3     42.0
# 866             1     27.0
# 867             3     31.0
# 868             3     25.0
# 869             3      4.0
# 870             3     26.0
# 871             3     47.0
# 872             3     33.0
# 873             3     47.0
# 874             1     28.0
# 875             1     15.0
# 876             3     20.0
# 877             3     19.0
# 878             3     25.0
# 879             1     56.0
# 880             3     25.0
# 881             3     33.0
# 882             3     22.0
# 883             3     28.0
# 884             3     25.0
# 885             2     39.0
# 886             3     27.0
# 887             3     19.0
# 888             3     21.5
# 889             1     26.0
# 890             2     32.0
#
# [891 rows x 11 columns]

# %%
# df
# df.describe()
# df.Sex.value_counts()
# df.Sex.value_counts().plot(kind='bar')
# df[df.Sex.isnull()]
# df[df.Sex == 'male']
# df.Fare.hist(bins=5)

###
#fig, axs = plt.subplots(1, 2)
#df[df.Sex == 'male'].Survived.value_counts().plot(kind='barh', ax=axs[0], title='male survived')
#df[df.Sex == 'female'].Survived.value_counts().plot(kind='barh', ax=axs[1], title='female survived')


passenger_classes = sorted(df['Pclass'].unique())
for pclass in passenger_classes:
    df.AgeFill[df.Pclass == pclass].plot(kind='kde')
plt.title('Age Density Plot by Passenger Class')
plt.xlabel('Age')
plt.legend(('1st Class', '2nd Class', '3rd Class'), loc='best')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-83-5398441f9e01> in <module>()
#      15 passenger_classes = sorted(df['Pclass'].unique())
#      16 for pclass in passenger_classes:
# ---> 17     df.AgeFill[df.Pclass == pclass].plot(kind='kde')
#      18 plt.title('Age Density Plot by Passenger Class')
#      19 plt.xlabel('Age')
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
#    3599                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3600                            **kwds)
#    3601     __call__.__doc__ = plot_series.__doc__
#    3602
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2672                  yerr=yerr, xerr=xerr,
#    2673                  label=label, secondary_y=secondary_y,
# -> 2674                  **kwds)
#    2675
#    2676
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in generate(self)
#    1041         self._compute_plot_data()
#    1042         self._setup_subplots()
# -> 1043         self._make_plot()
#    1044         self._add_table()
#    1045         self._make_legend()
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in _make_plot(self)
#    2099             kwds = self._make_plot_keywords(kwds, y)
#    2100             artists = self._plot(ax, y, column_num=i,
# -> 2101                                  stacking_id=stacking_id, **kwds)
#    2102             self._add_legend_handle(artists[0], label, index=i)
#    2103
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\tools\plotting.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#    2148     def _plot(cls, ax, y, style=None, bw_method=None, ind=None,
#    2149               column_num=None, stacking_id=None, **kwds):
# -> 2150         from scipy.stats import gaussian_kde
#    2151         from scipy import __version__ as spv
#    2152
#
# ImportError: No module named 'scipy'

# %%
cat_columns = df.select_dtypes(['category']).columns
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)
df_pre = df.fillna(df.mean())
#df_pre
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df_norm = df_pre/df_pre.max().astype(np.float64)
#df_norm = (df_pre - df_pre.mean()) / (df_pre.max() - df_pre.min())
df_norm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1169             result = expressions.evaluate(op, str_rep, x, y,
# -> 1170                                           raise_on_error=True, **eval_kwargs)
#    1171         except TypeError:
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     209         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 210                          **eval_kwargs)
#     211     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\computation\expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      62     with np.errstate(all='ignore'):
# ---> 63         return op(a, b)
#      64
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5558cd3ea72c> in <module>()
# ----> 1 df_norm = df_pre/df_pre.max().astype(np.float64)
#       2 #df_norm = (df_pre - df_pre.mean()) / (df_pre.max() - df_pre.min())
#       3 df_norm
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    1228             return self._combine_frame(other, na_op, fill_value, level)
#    1229         elif isinstance(other, ABCSeries):
# -> 1230             return self._combine_series(other, na_op, fill_value, axis, level)
#    1231         else:
#    1232             if fill_value is not None:
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in _combine_series(self, other, func, fill_value, axis, level)
#    3583                                                    fill_value=fill_value)
#    3584         return self._combine_series_infer(other, func, level=level,
# -> 3585                                           fill_value=fill_value)
#    3586
#    3587     def _combine_series_infer(self, other, func, level=None, fill_value=None):
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in _combine_series_infer(self, other, func, level, fill_value)
#    3595
#    3596         return self._combine_match_columns(other, func, level=level,
# -> 3597                                            fill_value=fill_value)
#    3598
#    3599     def _combine_match_index(self, other, func, level=None, fill_value=None):
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in _combine_match_columns(self, other, func, level, fill_value)
#    3615
#    3616         new_data = left._data.eval(func=func, other=right,
# -> 3617                                    axes=[left.columns, self.index])
#    3618         return self._constructor(new_data)
#    3619
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in eval(self, **kwargs)
#    3160
#    3161     def eval(self, **kwargs):
# -> 3162         return self.apply('eval', **kwargs)
#    3163
#    3164     def quantile(self, **kwargs):
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3054
#    3055             kwargs['mgr'] = self
# -> 3056             applied = getattr(b, f)(**kwargs)
#    3057             result_blocks = _extend_blocks(applied, result_blocks)
#    3058
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1157         try:
#    1158             with np.errstate(all='ignore'):
# -> 1159                 result = get_result(other)
#    1160
#    1161         # if we have an invalid shape/broadcast error
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in get_result(other)
#    1127
#    1128             else:
# -> 1129                 result = func(values, other)
#    1130
#    1131             # mask if needed
#
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1175                 result = np.empty(x.size, dtype=dtype)
#    1176                 yrav = y.ravel()
# -> 1177                 mask = notnull(xrav) & notnull(yrav)
#    1178                 xrav = xrav[mask]
#    1179
#
# ValueError: operands could not be broadcast together with shapes (1782,) (2,)
